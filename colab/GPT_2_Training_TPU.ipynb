# %%
# /shruggie

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#!rm -f ~/drive
#!ln -s /content/drive/My\ Drive ~/drive
# !mkdir -p /drive
#umount /drive
# !mount --bind /content/drive/My\ Drive /drive
# Out:
# Mounted at /content/drive
# mkdir: cannot create directory ‘/drive’: File exists

# %%
# !git clone https://github.com/flancian/gpt-2 /drive/gpt-2-botginia -b tpu-training
# %cd /drive/gpt-2-botginia
# Out:
# fatal: destination path '/drive/gpt-2-botginia' already exists and is not an empty directory.
# /drive/gpt-2-botginia

# %%
# don't see a need for this for now.
# !pip install magic-wormhole toposort regex fire
# nothing to wormhole for now, I think.
# !wormhole receive 3-october-briefcase --accept-file

# Fetch the corpus.
# This is just all of Virginia Woolf's works from Gutenberg AU, concatenated.
# !gsutil cp gs://botginia.appspot.com/woolf.txt .
# Out:
# Copying gs://botginia.appspot.com/woolf.txt...
# / [1 files][  6.7 MiB/  6.7 MiB]
# Operation completed over 1 objects/6.7 MiB.

# %%
# Available: 117M, 345M, 1.5B
# !python3 download_model.py 117M
# Out:
# Fetching checkpoint: 1.00kit [00:00, 735kit/s]
# Fetching encoder.json: 1.04Mit [00:00, 44.6Mit/s]
# Fetching hparams.json: 1.00kit [00:00, 727kit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:08, 57.7Mit/s]
# Fetching model.ckpt.index: 6.00kit [00:00, 4.01Mit/s]
# Fetching model.ckpt.meta: 472kit [00:00, 32.2Mit/s]
# Fetching vocab.bpe: 457kit [00:00, 39.7Mit/s]

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git config core.fileMode false
# !git pull
# Out:
# Already up to date.

# %%
# Default
# !PYTHONPATH=src python3 train.py --dataset woolf.txt --batch_size 32 --save_every 50 --sample_every 20 --sample_num 32 --sample_length 192 --save_on_ctrlc

# These are all lifted as-is from the other notebook I found.
# 117M
# !PYTHONPATH=src python ./train.py --dataset woolf.txt --batch_size 1 --save_every 100000 --sample_every 100 --init_tpu --fresh_model --n_ctx 1024 --n_embd 768 --n_head 12 --n_layer 12

# 345M
#!PYTHONPATH=src python ./train.py --dataset elisp-untab-eot-v001.txt.npz --batch_size 1 --save_every 100000 --sample_every 100 --init_tpu --fresh_model --n_ctx 1024 --n_embd 1024 --n_head 16 --n_layer 24

# 1.5B
# !PYTHONPATH=src python ./train.py --dataset elisp-untab-eot-v001.txt.npz --batch_size 1 --save_every 100000 --sample_every 100 --init_tpu --fresh_model --n_ctx 1024 --n_embd 1600 --n_head 25 --n_layer 48

# 117M with 2x the context
#!PYTHONPATH=src python ./train.py --dataset elisp-untab-eot-v001.txt.npz --batch_size 1 --save_every 100000 --sample_every 100 --init_tpu --fresh_model --n_ctx 2048 --n_embd 768 --n_head 12 --n_layer 12
# Out:
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/model.py:147: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/memory_saving_gradients.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# grpc://10.111.210.170:8470
# WARNING:tensorflow:From train.py:122: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From train.py:125: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Using TPU grpc://10.111.210.170:8470
# WARNING:tensorflow:From train.py:131: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/model.py:152: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/model.py:36: The name tf.rsqrt is deprecated. Please use tf.math.rsqrt instead.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/model.py:166: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/sample.py:65: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/sample.py:16: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /drive/gpt-2-botginia/src/sample.py:70: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# WARNING:tensorflow:From train.py:156: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# This model is using 124439808 parameters (118.68M)
# WARNING:tensorflow:From train.py:163: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From train.py:192: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From train.py:195: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From train.py:197: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From train.py:200: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From train.py:204: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# Loading checkpoint gs://sgappa-multi/gpt-2/models/117M/model.ckpt
# 2019-12-01 16:05:57.513787: W tensorflow/core/platform/cloud/google_auth_provider.cc:178] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "Not found: Could not locate the credentials file.". Retrieving token from GCE failed with "Cancelled: GCE check skipped due to presence of $NO_GCE_CHECK environment variable.".
# Loading dataset...
# 100% 1/1 [00:10<00:00, 10.70s/it]
# dataset has 1757429 tokens
# Training...
# [1 | 0.0005] Running opt_apply...
# [1 | 56.5672] Adding summary...
# [1 | 56.5676 | 56.57 | 0.565695/s] loss=3.8320 avg=3.8320
# [2 | 56.5681] Running opt_apply...
# [2 | 108.9998] Adding summary...
# [2 | 109.0002 | 52.43 | 0.610307/s] loss=3.6406 avg=3.7359
# [3 | 109.0008] Running opt_apply...
# [3 | 162.1735] Adding summary...
# [3 | 162.1738 | 53.17 | 0.601802/s] loss=3.5947 avg=3.6883
# [4 | 162.1746] Running opt_apply...
# [4 | 215.6141] Adding summary...
# [4 | 215.6144 | 53.44 | 0.598796/s] loss=3.6158 avg=3.6699
# [5 | 215.6150] Running opt_apply...
# [5 | 269.0538] Adding summary...
# [5 | 269.0543 | 53.44 | 0.598804/s] loss=3.6267 avg=3.6611
# [6 | 269.0548] Running opt_apply...
# [6 | 322.1493] Adding summary...
# [6 | 322.1497 | 53.10 | 0.602688/s] loss=3.7019 avg=3.6681
# [7 | 322.1503] Running opt_apply...
# [7 | 375.1575] Adding summary...
# [7 | 375.1578 | 53.01 | 0.603681/s] loss=3.4609 avg=3.6376
# [8 | 375.1584] Running opt_apply...
# [8 | 427.4516] Adding summary...
# [8 | 427.4519 | 52.29 | 0.611924/s] loss=3.5035 avg=3.6202
# [9 | 427.4525] Running opt_apply...
# [9 | 480.4323] Adding summary...
# [9 | 480.4329 | 52.98 | 0.603990/s] loss=3.4718 avg=3.6031
# [10 | 480.4336] Running opt_apply...
# [10 | 533.9036] Adding summary...
# [10 | 533.9040 | 53.47 | 0.598454/s] loss=3.5324 avg=3.5957
# [11 | 533.9045] Running opt_apply...
# [11 | 587.0734] Adding summary...
# [11 | 587.0737 | 53.17 | 0.601847/s] loss=3.5302 avg=3.5894
# [12 | 587.0744] Running opt_apply...
# [12 | 640.8345] Adding summary...
# [12 | 640.8347 | 53.76 | 0.595227/s] loss=3.5387 avg=3.5850
# [13 | 640.8354] Running opt_apply...
# [13 | 694.5274] Adding summary...
# [13 | 694.5277 | 53.69 | 0.595981/s] loss=3.5967 avg=3.5859
# [14 | 694.5283] Running opt_apply...
# [14 | 747.6169] Adding summary...
# [14 | 747.6173 | 53.09 | 0.602755/s] loss=3.5209 avg=3.5810
# [15 | 747.6180] Running opt_apply...
# [15 | 800.3853] Adding summary...
# [15 | 800.3856 | 52.77 | 0.606425/s] loss=3.6198 avg=3.5837
# [16 | 800.3864] Running opt_apply...
# [16 | 853.8575] Adding summary...
# [16 | 853.8578 | 53.47 | 0.598441/s] loss=3.5363 avg=3.5805
# [17 | 853.8584] Running opt_apply...
# [17 | 907.2626] Adding summary...
# [17 | 907.2630 | 53.41 | 0.599194/s] loss=3.5243 avg=3.5770
# [18 | 907.2635] Running opt_apply...
# [18 | 960.0705] Adding summary...
# [18 | 960.0708 | 52.81 | 0.605970/s] loss=3.5050 avg=3.5726
# [19 | 960.0714] Running opt_apply...
# [19 | 1013.3640] Adding summary...
# [19 | 1013.3644 | 53.29 | 0.600448/s] loss=3.5616 avg=3.5720
# Generating samples...
# ======== SAMPLE 1 ========
#
#
# "You should have found a book about them."
#
# I nodded, but the idea seemed to waver. "I know all about some who make their own lives. I'm sure that there are some who are in need of something. But I can't find a book, which I can read. I'll buy it."
#
# "Yes."
#
# I said my name, and the room became silent. The smell became more distinct from the others.
#
# "I would like you to come into me again. I promise that if you come here you shall see me again. All right. There is nothing left for me, and I will be as much as your father had wished you. You will think my voice is no better. I shall be your father. We love you all, my darling, and all these years, we will always be one."
#
# "I suppose this is a great plan."
#
# "
#
# ======== SAMPLE 2 ========
#
# It was a pretty good week as a fan as there was a lot of action from the crowd as they played the first part of Season 3. The music as well as the music made it very clear how the group had their moments at the top of their game and now have to face off against another new group.
# I think it's pretty cool that this year at least for us is seeing some pretty cool group that can play different songs without much fuss about each other. This was quite a positive step for our team to make, to let their emotions get the better of them and make sure that we got the best of the best and got them to play on the same stadium in the same stadium as them. I still think it was great and it was fun when our guys played with some really cool people in there. That was nice, that's going to be good. The second half of the season it was almost as much fun playing with a bunch
#
# ======== SAMPLE 3 ========
#
#
# I thought about leaving the place.
#
# "It's too dangerous."
#
# "I need to go."
#
# "We have to take it," I said. I had nothing to do there. I just wandered off and picked up a bottle of milk—all those little words I could think of. I didn't speak to those people much, but, now and then, they spoke. I found the only people in the room who seemed to be listening at all. I looked on them, in the middle of a row of seats or rows and rows of children on a table.
#
# "I am too young for anything," they said. "We need a place to live. They want a place to stay. They want a place where you do what you are allowed to do—you are allowed to talk to women, you are allowed to take pictures of people. Now, as it were, we were out a hundred miles
#
# ======== SAMPLE 4 ========
#
#
# In a press release, the U.S. Food and Drug Administration said the company was making "reasonable modifications" to its product, including rebranding.
#
# "In order to meet our FDA regulations and comply with FDA guidelines, all of our products are now rebranded," Dr. Mark S. Hirsch, director of the agency's Division of Food and Drug Administration, said in a statement. "The company believes that our label should not be confusing and should not be misleading or overly aggressive, as it has done in past product reviews."
#
# Dr. Peter D. Storbeck, a professor of medicine and biostatistics at the University of California-Berkeley and chief executive of the American Society of Cancers, agreed: "We see this as an opportunity to make sure the FDA doesn't get rid of products that don't adhere to the label."
#
# The change has not been universally welcomed among companies in the
#
# ======== SAMPLE 5 ========
#
# 1 x 2 pkg 3,1 ounce
#
# 1 x 2 pkg 6,1 ounce
#
# 1 x 6 pkg 8,1 ounce
#
# 1 x 8 pkg 10,1 ounce
#
# 1 x 10 pkg 12,1 ounce
#
# 1 x 11 pkg 13,1 ounce
#
# Protein: Calories: 160
#
# Dietary cholesterol: 1.
#
# Fat: 7.
#
# Sodium: 7.
#
# Carbohydrate: 12.
#
# Cholesterol: 22
#
#
# Protein: Calories: 155
#
# Dietary cholesterol: 7.
#
# Fat: 8.
#
# Sodium: 16.
#
# Carbohydrate: 12.
#
# Cholesterol: 26
#
#
# Protein: Calories: 165
#
# Dietary cholesterol: 8.
#
# Fat: 10.
#
# Sodium: 22.
#
# Carbohydrate: 16.
#
#
#
# ======== SAMPLE 6 ========
#
# A note about all this discussion about the new world order: The idea of an "inversion" of the modern world is an idea of itself, a contradiction created by reason and reason alone, in some manner or other, and yet I think that it has succeeded in being true; though I know that it is not the world order that will give an appearance to the contradictions that need to be abolished. I consider it, after all, a very serious question in history as to whether this must be done, in order that, as some have claimed, the world will be transformed into one that is harmoniously balanced. And if, in order that, in such a world, the balance of forces changes and becomes changed, so that there are no contradictions in this harmony, then, I should wish that we were talking about what we called a world in which one may be equal in rank with others.
#
# The idea in which the world differs is a
#
# ======== SAMPLE 7 ========
#
#
# Ridley-Clark, M. (2004). Self-regulation and the psychology of self-regulation and regulation.
#
# Sutton, N. (2007). The effect of age, gender and race on the effects of social anxiety.
#
# Sutton, N., B.M.M. (1993). Self-regulation.
#
# Stevenson, M., B.E.R. (2002). A review of the literature: a review.
#
# Tillman, D. (2004). Does society's influence on self-regulation and self-regulation is moderated by an age?
#
# Krause, A., P.W.S. (2004). Can age-related and demographic factors change the influence of social anxiety?
#
# Wilson, H. W., A.S.T. (2010). "Psychological influences on attitudes about health and disease."
#
# Wilson, H.W.,
#
# ======== SAMPLE 8 ========
#
#
# The New York state House of Representatives passed the bill. The bill had passed a House vote three weeks before but is currently in limbo. The legislation had passed only three houses and will be debated in New York's state assembly.<|endoftext|>This weekend's NBA draft had its fair share of controversy, although not in the way it's often done. Last night, an NBA rule change took effect that changed the league's Draft Day rules. The new rule change in the summer and the new NBA rule changes in next year, are being discussed by draft experts and fans looking to draft for their young players, but they're not the only teams that have had problems with this season's draft.
#
# There are two major differences at play. The first is that when you draft the draft players in advance you must do so before you start planning in an attempt to get any draft picks. So now, the team that gets to pick the draft picks that they already own
#
# ======== SAMPLE 9 ========
#
# , with his friends, and with the boys, and the girls, and the one in the car who was always sitting outside, and who had nothing to be frightened of.
#
# He had no idea whether he could use that time of night to do business, or the work of his mind to give to others. His only hope of seeing or speaking came with the sound of a sound coming from the window, then the sound of a whistle. It struck, to which she thought it was a wind blowing, and he thought that it was a little wind, or a little flute like it. He came into the room he had been talking with the night previously, and found the window open. He opened it in a little window of a little room beside the little fireplace. It was all shut. He opened his handkerchief again. So the man who had just made the whistle and had a little cigarette with him put into the cigarette cabinet,
#
# ======== SAMPLE 10 ========
#
#
# The next day, the woman's body was found in the woods near a creek.
#
# Investigators were called to the scene within minutes, according to the report.
#
# A video taken from the area shows the driver of a truck approaching the woman's body before it disappears.
#
# The video shows the person lying on his left in water. Investigators say they will never know if the suspect or suspects did anything more than that, but it is possible.
#
# A man, whose name was not released, said he and his wife had been driving home from a party. At the party, they drank a beer and passed him a note. Later that night, they noticed that the party was gone.
#
# "They were drinking," said the man, who asked not to be identified due to the sensitivity of the case.
#
# During this time, the man said, he was approached by two friends who told him they found a corpse hanging
#
# ======== SAMPLE 11 ========
#
#
# He was born in London in 1913 and has three children. In the US that's nine children.
#
# Karen Smith, the director of the Center for American Progress, the liberal think tank that promotes a "America first" philosophy as much as any other group or government, said, "We do not believe that every American should take on the role of chief advocate of American values and our moral authority."
#
# She and others at the group, she said, are "anxious to be part of a society that is a society for everybody."<|endoftext|>We're looking for people who can work in IT, marketing, video editing, software engineering, video game development or digital media. We'll be able to give you the best experience possible and ensure you have the best quality of work possible.
#
# We're looking for people who work in IT, marketing, video editing, software engineering, video game development or digital media. We'll be able
#
# ======== SAMPLE 12 ========
#
# The only major differences from the original Japanese text are the spelling and the characters. However, a good-looking copy of Chapter 1 contains seven pages of the original text.
#
# I found the following text in a box marked "Japanese."
#
# On the left side of the picture is this page:
#
# CHAPTER 1
#
# "The Devil, and Love." The picture hangs on the wall of my hotel room. I see the picture of the Devil on the wall and my father lying in bed.
#
# "I don't know what God has written," says my father.
#
# "How?" says one of his friends.
#
# "The Devil writes in the past. All of the Devil's works are written in the past."
#
# "Do you know a story that makes this look good?" asks another.
#
# "You will be disappointed when you see it," says my father.
#
# "You will see it,"
#
# ======== SAMPLE 13 ========
#
#
# I did not have enough room for another book, but I was ready to drop everything into my pocket, so I headed for bookshelves and bookshelfs. The weather on this island is quite cold. The only time the islands are on the road is when there is a hot night. I decided to go to a bookstore for my book collection. There is a lot of books here.
#
# There was a bookshop on one of the trees in Thessaloniki, another was a cafe in the city center. So I did not miss out on anything. I was ready to start a new book tour when I felt that I knew enough about books to find a bookshop nearby in Thessaloniki to pick it up from the shelf that was in my pockets.
#
#
# I was glad that I made it this far with a book-reading goal in mind, not really an exercise to be made into art, although I should
#
# ======== SAMPLE 14 ========
#
# s.p.p.h, and we will see in particular the use of this title in a different way.
#
# A
#
# .
#
# .
#
# S. S. V. M.
#
# S. S. V. M
#
# A
#
# .
#
# S. S. V. M.
#
# A
#
# .
#
# S. S. V. M.
#
# S. S. V. M.
#
# A
#
# .
#
# .
#
# S. S. V. M.
#
# A
#
# .
#
# .
#
# V. M.
#
# This is only one of many books and pamphlets we have published during the last year. Some have been reprinted in our own collection at home: 'S. V. M.', 'S. V. M. is the Book of the World', 'M.E.A.', 'P.
#
# ======== SAMPLE 15 ========
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Brett McKay
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr. Green
#
# Mr.
#
# ======== SAMPLE 16 ========
#
#
# It's not clear where the idea came from, or where the concept was brought up until, last week, at the same meeting of the American Enterprise Institute, a group that supports the separation of church and state, when, it seems, all sorts of people were going to be discussing how to reconcile religion to freedom and equality, which is exactly what the Bible says. (Note that the idea of a government on the one hand, and one person holding the torch on the other hand, in the same way the Romans said to the Jews, "You ought to hold to your own religion")
#
# In fact, by the second week on this very first day, the idea that the right of church worship is based upon a person's private and individual beliefs began to stir in the American consciousness.
#
# There was the discussion about the need for "freedom" in government, a point of view so deeply held at the time that the American government decided
#
# ======== SAMPLE 17 ========
#
# , and .
#
# The book that is available and for sale is "W.P.P." (This title was not taken directly from the book, but is an excerpt from an essay in the book by William W. Pierce), which is based on a review by William M. Brown of James G. Burt's (1910) book The World That Grows Up.
#
# Here is what happens for the American people. For all the people who are engaged in the business of producing a book, they are looking for somebody who will be honest; somebody who will be a good man in a good deal; someone who will be well received. They will know this because they have a common enemy—the great men; they have a common enemy—the Great Depression—the Great Powers. The Americans are, by and large, the people, and you know what that means in the United States. But the fact is, as I will
#
# ======== SAMPLE 18 ========
#
# In the wake of the shooting, several state agencies — including New Jersey and New York — raised concerns over the use of deadly force, including the use of tear gas against demonstrators, and state legislatures, led by New York, raised concerns over the use of stun-gun use against demonstrators and other law-abiding citizens.
#
# The state Senate recently adopted a resolution addressing the use of force and the use of pepper spray against protesters. Legislators are scheduled to vote on the resolution Tuesday.
#
# The National Guard was dispatched to the scene.
#
# The Army sent five reservists as part of the force and three Army officers deployed.
#
# State Rep. Tim Breen, R-Worthington, said at the scene that he believed the incident was isolated because the shooting was so violent.
#
# "We know what happened to us, but we know what happened to our children. We are not going to let that happen," Breen
#
# ======== SAMPLE 19 ========
#
#
# "We've done a couple of things to stop those types of attacks that are going to happen in Iraq," said the former Pentagon official. The Department of Defense maintains an air and ground defense capability that is deployed all over the country.
#
# The Obama administration has said it has a strategy for combatting the weapons of mass destruction and it is looking into the possibility of getting involved in "other operations."
#
# The White House has said it intends to spend at least $1 billion worth of money on anti-terrorism and counter-terrorist efforts, which it said could be used in Iraq.<|endoftext|>SINGAPORE (Thomson Reuters Foundation) - Singapore on Wednesday gave its support to the government of Prime Minister Lee Hsien Loong but said its opposition would not be part of any final decision on future trade deals.
#
# Prime Minister Lee Hsien Loong walks as he arrives to greet people during the opening ceremony at the Seng
#
# ======== SAMPLE 20 ========
#
#
# It would be in a few weeks we'll be happy for another new book:
#
# Travelling to Italy.
#
# The book, by Tim Burton and illustrated by Andy Warhol, is due for first printing October 29th.
#
# I'm sure we've all seen this before here on ComicBook.
#
# Please take a minute and vote for them.
#
# To get some copies available, use the following code to unlock them:
#
# 1D0f9zPqR_5fVh
#
# You can find all of our first-printing editions here: http://gutenberg.org/ebooks/
#
# Read and follow us on Twitter @DCMagazine and like us on Facebook.
#
# More from Comic Book Resources here:
#
# - Comics and Comic Books for Kindle - Volume 10
#
# - Comics that were in hardcover
#
# Please give us a little bit of help via Patreon
#
# ======== SAMPLE 21 ========
#
#
# Risk
#
# A risk may result in having an injured motorist on scene with a potential motor vehicle involved in the incident.
#
# Travelling in the lane of traffic does not necessarily automatically result in a dangerous driving position. The risk should therefore be considered at its highest during an emergency situation when the road is relatively narrow or the vehicle is not a hazard to the public.
#
# Drivers should also be vigilant in any incidents of public nuisance involving their licence holder, if they may be involved in public nuisance, such as with children in or across a vehicle.
#
# Any person wishing to remain behind on the road should use his or her position to prevent motorists from overtaking or slowing the vehicle.
#
# Drivers travelling on the right lane must obey and avoid the traffic lights and road traffic signals in the normal course. They should also yield traffic-control points to motorists who are using the right-angle road.
#
# A rear
#
# ======== SAMPLE 22 ========
#
# I've also been to the same bookshop where the boys worked, only to encounter the same strange people, the same strange people.
#
# There was a man who came at the counter in the late twenties asking for some sort of tea, and they all said, "This man's English is so good he can't understand any of us, and he only speaks English to people he can't understand."
#
# In addition to this, the woman also said nothing, and when my aunt, who was standing beside me, saw something she thought was in question, she went down with her eyes shut; then I saw somebody sitting at a table with a huge tray of coffee, and she said something, and then everybody went back to the table. I thought she was going to say something rude and rude. It was a good one, and what more could she say?
#
# In another way, I could feel myself, as a woman, being
#
# ======== SAMPLE 23 ========
#
#
# One of those who had his arms stretched out over his body is, of course, Josephine. She is married and has an open family. She is the wife of William the Third, and Joseph Smith is the mother. Joseph was born at this house at four o'clock in the morning. She went out at about twelve o'clock in the afternoon, and went straight home the next morning, and we have a little time to discuss that which is to come. But I think we should ask ourselves whether the family is so small as to become a family, whether we should be able to conceive children. They are a small family, in the sense that they have one little child—this little man, this little boy. When they have the world to themselves, they come to themselves.
#
# In my view the family is very small in these cases—I mean, it is so little, it is so small, they have no power
#
# ======== SAMPLE 24 ========
#
# - Added the feature for the following devices: Samsung Galaxy S II (S5), Note 2 (S5+), Galaxy C7 (N9), and the new S5 Black, Black, and Blue models.
#
# - Improved compatibility of the new devices with HTC One (N9), One M9, Droid RAZR (N9+), and S13.
#
# - A new 'Laptop Mode' system has been added.
#
# - Updated the default setting (in the System Settings) to match the new keyboard.
#
# - Added the ability to choose the number of active key presses (0 to 1) by swiping the Home key in the left corner of the screen in order to make the keyboard switch to 'Lame keyboard' mode.
#
# - Added a custom font size.
#
# - Several new images, such as 'Stunning' on the screen (and 'Rocking') and 'Perfect
#
# ======== SAMPLE 25 ========
#
# 3rd Party Games & Books : $2.00
#
# : $2.00 4th Party Games & Books: $2.00
#
# : $2.00 5th Party Games & Books: $2.00
#
# 6th Party Games & Books: $2.00
#
# 7th Party Games & Books: $2.00
#
# 8th Party Games & Books: $2.00
#
# 9th Party Games & Books: $2.00
#
# 10th Party Games & Books: $2.00
#
# 11th Party Games & Books: $2.00
#
# 12th Party Games & Books: $2.00
#
# 13th Party Games & Books: $2.00
#
# 14th Party Games & Books: $2.00
#
# 15th Party Games & Books: $1.50
#
# Etrian Odyssey : $9.95
#
# : $
#
# ======== SAMPLE 26 ========
#
#
# I'm sorry for the trouble. Don't touch my hand when I'm going to do something.
#
#
# The sun's still the only light;
# He can't see him.
#
#
# But I'm still able to see him
# in his own way.
#
#
# His own self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-conscious self-
#
# ======== SAMPLE 27 ========
#
# Sebastian Klassmann is the first senior manager to admit the team has struggled to find form.
#
# The Germany boss announced that he hopes he can help turn his side into a title contender again.
#
# As a result, he added, Germany will need to find ways to overcome relegation.
#
# It is expected the new regime should be able to bring in enough players to help change the complexion of the Premier League season and help them to establish their place in the Champions League group stage.
#
# Sebastian Klassmann says, "We need to help create that sense of stability that has gone out of the football team."
#
# Meanwhile, the United States is also set to host Chile in the final for a group which had featured the United States on two occasions before.
#
# The US president has told a meeting of FIFA President Sepp Blatter: "All we need from our football organisation is that we can start
#
# ======== SAMPLE 28 ========
#
# <|endoftext|>Halo 5 Remastered
#
# Here is what I've been up to since they were released on Xbox One last year:
#
# And with all the progress they've made since then we are expecting a big jump in release time.
#
# The release date to date was still being announced but there is still the announcement date to consider.
#
# Now, while I've been able to say, and have the opportunity to see, the things we've seen so far is what we have to work with at launch.
#
# Here's the update from Microsoft (on their website):<|endoftext|>Derek McNeill is now in the thick of things, after being forced to withdraw from the club and the squad over a sexual relationship.
#
# He told the Scottish Daily Record: "I got myself kicked out and it wasn't that because I didn't want to be involved, but because I thought it was wrong.
#
# "There are lots of people who
#
# ======== SAMPLE 29 ========
#
#
# In the fall of 1993 he was in Rome attending the Vatican's famous Forum upon Christian Principles for Human and Philosophical Reason. While the occasion was celebrated a few days later at the St. Peter's Basilica he received a call "from Heaven to sit and observe," a "familiar event" in the history of Christianity, which he called "the first and most sacred of all religious festivals," and a "great victory in the cause of the Christian religion."
#
# Notwithstanding all this, on March 15, 1993, he stood in front of the great square before the cathedral of St. Peter's to hear from Pope Paul V.
#
# "The meeting of the Church has come, and in my hands I stand this hour. There is no question of peace here. The church now is in peace, and the church is in war for us. What should this meeting mean to us?"
#
# He paused a bit. "Well,"
#
# ======== SAMPLE 30 ========
#
# The current record-breaking record of 469.8 million viewers for AMC was confirmed Wednesday by the network.
#
# In other programming:
#
# The second season of the sci-fi drama "The Good Wife" has earned 7.1 million, the highest on the series.
#
# The third season of the series' original drama "The Handmaid's Tale" has grossed 4.8 million, up 3%, for the fifth consecutive season.
#
# "The Good Wife" is rated R for adults 18-49 for 16 weeks (live plus same-day ratings; 13,600 adults 18-34, 1,000 adults 18-34 & 11,800 adults 18-34), and its rating in the key demo has been updated.
#
# TV.com has learned that "True Detective" creator Damon Lindelof is in talks to star alongside Mark Strong in a new show that was originally developed and written by Jeph Lo
#
# ======== SAMPLE 31 ========
#
# There are also some interesting questions left unanswered, like when to do this and what will happen if the game ends at 8:00am. Is this the end of the postgame chat window or is the next game still open?
#
# A little background information about my game before it opened:
#
# I am currently working on the game itself! You can now play it here.
#
# All game information is provided in this guide for players who wish to be able to play it.
#
# I apologize for a bit of a delay in the game. I hope to fix and improve very soon!<|endoftext|>The European Union's latest attempt to ban the sale and sale of cocaine to Saudi Arabia and other Gulf countries goes the extra mile in creating a global image problem. It's because we can't do anything good without getting our heads out of our asses, particularly when it's our friends who are exploiting our vulnerability.
#
# It's obvious that while the
#
# ======== SAMPLE 32 ========
#
# 3. Make sure your home address is not the home of a landlord
#
# 1. A person who holds the land title to private property must not reside in a dwelling unit in which he or she lives but is within the meaning of subsection 1(14) (3).
#
# A person held by the landlord to be living in a dwelling unit must not be in possession of a dwelling unit who is held to be at least 17 years of age and who is not more than 16 years of age.
#
# The landlord must hold to be at least 21 years of age the person to whom you are entitled to occupy the dwelling unit with the landlord in an agreement with him or her, as the case may be, and not to be in possession of property, other than a dwelling unit in which you or he are not at arm's length.
#
# It is unlawful for an occupant of an accommodation in which he or she is not at arm's length
#
# [20 | 1061.1217] Running opt_apply...
# [20 | 1116.3033] Adding summary...
# [20 | 1116.3037 | 102.94 | 0.310863/s] loss=3.5114 avg=3.5687
# [21 | 1116.3043] Running opt_apply...
# [21 | 1169.4035] Adding summary...
# [21 | 1169.4038 | 53.10 | 0.602636/s] loss=3.4580 avg=3.5628
# [22 | 1169.4051] Running opt_apply...
# [22 | 1222.5061] Adding summary...
# [22 | 1222.5063 | 53.10 | 0.602608/s] loss=3.5731 avg=3.5634
# [23 | 1222.5068] Running opt_apply...
# [23 | 1275.7681] Adding summary...
# [23 | 1275.7684 | 53.26 | 0.600802/s] loss=3.5431 avg=3.5624
# [24 | 1275.7691] Running opt_apply...
# [24 | 1329.4706] Adding summary...
# [24 | 1329.4709 | 53.70 | 0.595876/s] loss=3.5494 avg=3.5618
# [25 | 1329.4725] Running opt_apply...
# [25 | 1382.4143] Adding summary...
# [25 | 1382.4146 | 52.94 | 0.604416/s] loss=3.5065 avg=3.5593
# [26 | 1382.4151] Running opt_apply...
# [26 | 1435.8022] Adding summary...
# [26 | 1435.8024 | 53.39 | 0.599387/s] loss=3.4804 avg=3.5559
# [27 | 1435.8030] Running opt_apply...
# [27 | 1489.0139] Adding summary...
# [27 | 1489.0141 | 53.21 | 0.601371/s] loss=3.5495 avg=3.5556
# [28 | 1489.0153] Running opt_apply...
# [28 | 1542.0525] Adding summary...
# [28 | 1542.0527 | 53.04 | 0.603335/s] loss=3.5034 avg=3.5535
# [29 | 1542.0534] Running opt_apply...
# [29 | 1594.6105] Adding summary...
# [29 | 1594.6108 | 52.56 | 0.608850/s] loss=3.5370 avg=3.5528
# [30 | 1594.6114] Running opt_apply...
# [30 | 1648.0041] Adding summary...
# [30 | 1648.0044 | 53.39 | 0.599323/s] loss=3.4899 avg=3.5504
# [31 | 1648.0050] Running opt_apply...
# [31 | 1701.2633] Adding summary...
# [31 | 1701.2636 | 53.26 | 0.600836/s] loss=3.4780 avg=3.5477
# [32 | 1701.2641] Running opt_apply...
# [32 | 1754.5744] Adding summary...
# [32 | 1754.5746 | 53.31 | 0.600251/s] loss=3.4382 avg=3.5437
# [33 | 1754.5752] Running opt_apply...
# [33 | 1807.8473] Adding summary...
# [33 | 1807.8476 | 53.27 | 0.600680/s] loss=3.5174 avg=3.5428
# [34 | 1807.8482] Running opt_apply...
# [34 | 1860.6926] Adding summary...
# [34 | 1860.6929 | 52.85 | 0.605542/s] loss=3.4887 avg=3.5409
# [35 | 1860.6938] Running opt_apply...
